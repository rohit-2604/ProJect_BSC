# %% [markdown]
# ***Dataset Analysis @Area_03_ B.S._ROAD***

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/air_bsroad_avg.csv')

# %%
print (data)
# Out:
#      Time    CO2  Toluene     NH4  Acetone     CO
# 0   06:45  1.544    0.264   2.548    0.228  2.213
# 1   06:46  1.445    0.243   2.407    0.211  2.152
# 2   06:47  1.389    0.231   2.328    0.200  2.122
# 3   06:48  1.356    0.225   2.279    0.194  2.099
# 4   06:49  1.186    0.192   2.028    0.167  1.991
# 5   06:50  0.983    0.151   1.727    0.134  1.912
# 6   07:15  2.648    0.504   4.068    0.429  3.033
# 7   07:16  2.353    0.436   3.671    0.374  2.831
# 8   07:17  2.124    0.386   3.350    0.331  2.669
# 9   11:15  5.324    1.171   7.432    0.980  4.444
# 10  11:16  5.793    1.294   7.997    1.080  4.687
# 11  11:17  5.800    1.296   8.010    1.380  4.633
# 12  11:18  5.697    1.271   7.884    1.059  4.507
# 13  19:15  6.823    1.593   9.163    1.321  6.058
# 14  19:16  8.128    1.952  10.400    1.613  6.157
# 15  19:17  8.081    2.059  11.160    1.698  6.500

# %%
time = data.iloc[2:, 0]  # Assuming the time starts from the third row
co2 = data.iloc[2:, 1].astype(float)
toluene = data.iloc[2:, 2].astype(float)
nh4 = data.iloc[2:, 3].astype(float)
acetone = data.iloc[2:, 4].astype(float)
co = data.iloc[2:, 5].astype(float)

# %%
# Create a line plot for CO2
plt.plot(time, co2, label='CO2')

# Create a line plot for Toluene
plt.plot(time, toluene, label='Toluene')

# Create a line plot for NH4
plt.plot(time, nh4, label='NH4')

# Create a line plot for Acetone
plt.plot(time, acetone, label='Acetone')

# Create a line plot for CO
plt.plot(time, co, label='CO')

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Gas Levels')
plt.title('Gas Levels over Time @B.S.ROAD')

# Rotate x-axis tick labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend()

# Show the line plot
plt.show()
