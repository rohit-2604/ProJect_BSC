# %% [markdown]
# ***Dataset Analysis @Area_1_ Sujapur***

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/air_sujapur_avg.csv')

# %%
print (data)
# Out:
#      Time    CO2  Toluene    NH4  Acetone     CO
# 0   11:30  2.847    0.551  4.332    0.469  3.209
# 1   11:31  3.009    0.587  4.524    0.498  3.237
# 2   11:32  3.203    0.634  4.795    0.538  3.247
# 3   11:33  3.261    0.647  4.871    0.549  3.138
# 4   11:34  3.287    0.654  4.902    0.554  3.053
# 5   11:35  3.278    0.651  4.894    0.551  2.997
# 6   14:47  2.672    0.485  4.099    0.433  3.118
# 7   14:48  2.720    0.522  4.162    0.441  3.178
# 8   14:49  2.505    0.472  3.814    0.398  3.027
# 9   14:50  2.068    0.376  3.280    0.325  2.688
# 10  14:51  1.568    0.269  2.582    0.231  2.448
# 11  14:52  1.733    0.303  2.817    0.261  2.581
# 12  14:53  1.849    0.328  2.979    0.282  2.629
# 13  14:54  1.920    0.342  3.078    0.294  2.689

# %%
time = data.iloc[2:, 0]  # Assuming the time starts from the third row
co2 = data.iloc[2:, 1].astype(float)
toluene = data.iloc[2:, 2].astype(float)
nh4 = data.iloc[2:, 3].astype(float)
acetone = data.iloc[2:, 4].astype(float)
co = data.iloc[2:, 5].astype(float)

# %%
# Create a line plot for CO2
plt.plot(time, co2, label='CO2')

# Create a line plot for Toluene
plt.plot(time, toluene, label='Toluene')

# Create a line plot for NH4
plt.plot(time, nh4, label='NH4')

# Create a line plot for Acetone
plt.plot(time, acetone, label='Acetone')

# Create a line plot for CO
plt.plot(time, co, label='CO')

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Gas Levels')
plt.title('Gas Levels over Time @SUJAPUR')

# Rotate x-axis tick labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend()

# Show the line plot
plt.show()
