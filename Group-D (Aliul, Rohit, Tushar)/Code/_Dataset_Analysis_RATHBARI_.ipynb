# %% [markdown]
# ***Dataset Analysis @ Area _04_RATHBARI***

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/air_rathbari_avg.csv')

# %%
print (data)
# Out:
#      Time    CO2  Toluene     NH4  Acetone     CO
# 0   06:45  3.435    0.689   5.092    0.583  3.501
# 1   06:46  3.752    0.766   5.498    0.645  3.625
# 2   06:47  3.593    0.729   5.296    0.614  3.531
# 3   06:48  3.407    0.682   5.058    0.579  3.442
# 4   11:15  9.946    2.477  12.760    2.038  6.844
# 5   11:16  9.275    2.279  12.010    1.875  6.886
# 6   11:17  7.586    1.789  10.100    1.490  6.365
# 7   11:18  6.200    1.403   8.483    1.170  6.400
# 8   17:10  4.326    0.910   6.214    0.765  4.107
# 9   17:11  3.454    0.695   5.115    0.588  3.930
# 10  17:12  3.465    0.698   5.130    0.589  3.853

# %%
time = data.iloc[2:, 0]  # Assuming the time starts from the third row
co2 = data.iloc[2:, 1].astype(float)
toluene = data.iloc[2:, 2].astype(float)
nh4 = data.iloc[2:, 3].astype(float)
acetone = data.iloc[2:, 4].astype(float)
co = data.iloc[2:, 5].astype(float)

# %%
# Create a line plot for CO2
plt.plot(time, co2, label='CO2')

# Create a line plot for Toluene
plt.plot(time, toluene, label='Toluene')

# Create a line plot for NH4
plt.plot(time, nh4, label='NH4')

# Create a line plot for Acetone
plt.plot(time, acetone, label='Acetone')

# Create a line plot for CO
plt.plot(time, co, label='CO')

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Gas Levels')
plt.title('Gas Levels over Time @RATHBARI')

# Rotate x-axis tick labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend()

# Show the line plot
plt.show()
